# %%
import pygame
import os
import sys

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import numpy as np
from PIL import Image
import random
import matplotlib.pyplot as plt
from matplotlib import animation
from collections import deque
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.10.16)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
print(torch.cuda.is_available())  # 應該為 True
print(torch.version.cuda)         # 應該列出 CUDA 版本
print(torch.backends.cudnn.version())  # cuDNN 版本
# Out:
# True
# 12.1
# 90100

# %%
script_dir = os.path.join(os.getcwd(), 'space_ship_game_RL')
if script_dir not in sys.path:
    sys.path.append(script_dir)

from setting import *
from game import Game

# %%
class SpaceShipEnv():
    def __init__(self):
        pygame.init()
        pygame.font.init()

        # 延後畫面初始化，等 render() 時才設置
        self.screen = None
        self.clock = pygame.time.Clock()
        self.fps = FPS

        self.game = Game()

        self.action_space = [0, 1, 2, 3]
        self.observation = self.game.state

    def step(self, action):
        old_score = self.game.score
        old_health = self.game.player.sprite.health

        self.game.update(action)

        if self.screen is None:
            self.game.draw()
        else:
            self.game.draw(self.screen)
            self.clock.tick(self.fps)

        state = self.game.state

        # 初始化 reward
        reward = 0.0

        # 擊中石頭
        if self.game.is_hit_rock:
            reward += 2.0

        # 撿到道具
        if self.game.is_power:
            reward += 2.0

        # 撞到石頭
        if self.game.is_collided:
            reward -= 5.0

        # 分數獎勵
        score_diff = self.game.score - old_score
        reward += score_diff * 0.1  # 比例可調整

        
        # 存活獎勵
        reward += 0.05

        done = not self.game.running or self.game.score >= 10000
        info = self.game.score

        return state, reward, done, info


    def reset(self):
        self.game = Game()

        return self.game.state

    def render(self):
        if self.screen is None:
            self.screen = pygame.display.set_mode((WIDTH, HEIGHT))
            pygame.display.set_caption("SpaceShip RL Environment")

    def close(self):
        pygame.quit()

# %%
# Hyperparameters
num_episodes = 2000
batch_size = 64
gamma = 0.99
lr = 1e-4
epsilon_start = 1.0
epsilon_end = 0.01
gradient_clip = 5.0  # 防
epsilon_decay = 0.999
memory_capacity = 60000  # 100000
target_update_freq = 2000   # 1000

# %%
epsilon_list=[]
epsilon=epsilon_start
for i in range(num_episodes):
    epsilon = max(epsilon_end, epsilon * epsilon_decay)
    epsilon_list.append(epsilon)
plt.plot(epsilon_list)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# CNN-based DQN Model
class DQN(nn.Module):
    def __init__(self, num_actions):
        super(DQN, self).__init__()
        self.conv1 = nn.Conv2d(4, 32, kernel_size=8, stride=4)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)
        self.fc1 = nn.Linear(64 * 7 * 7, 512)
        self.fc2 = nn.Linear(512, num_actions)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        return self.fc2(x)

# %%
# Replay buffer
# 用於儲存代理人經驗（狀態、動作、獎勵等）的緩衝區，支援隨機抽樣以打破時間相關性，有助於穩定訓練。

class ReplayMemory:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)
        # Use deque with a fixed capacity to automatically discard the oldest experience when full.
        # 使用 deque 並設定最大長度，當容量滿時會自動移除最舊的資料。

    def push(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))
        # Store a single transition (experience) in the buffer.
        # 儲存一筆經驗（狀態轉移）進緩衝區。

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        # Randomly sample a batch of transitions to break correlation between consecutive samples.
        # 隨機抽取一批經驗，打破樣本間的時間關聯性，提高訓練穩定性。

        # Unpack each element into separate tensors for network input
        # 將 batch 拆解成分別的 tensor 以供神經網路訓練
        states, actions, rewards, next_states, dones = zip(*batch)
        
        # Convert the sampled data into tensors and move them to the specified device (CPU or GPU)
        # 將抽樣資料轉成 tensor 並移至指定設備（CPU/GPU）
        states = torch.tensor(np.stack(states), dtype=torch.float32, device=device)
        actions = torch.tensor(actions, dtype=torch.int64, device=device)
        rewards = torch.tensor(rewards, dtype=torch.float32, device=device)
        next_states = torch.tensor(np.stack(next_states), dtype=torch.float32, device=device)
        dones = torch.tensor(dones, dtype=torch.float32, device=device)
        
        return states, actions, rewards, next_states, dones

    def __len__(self):
        return len(self.buffer)
        # Return the current size of the buffer.
        # 回傳緩衝區目前儲存的資料數量。

# %%
# Preprocess frames (grayscale and resize to 84x84)
# 預處理影格：轉為灰階並縮放為 84x84

def preprocess_frame(frame):
    # frame 是 numpy array (H, W, 3)，先轉為 PIL Image
    # Input is a color image (RGB), convert to PIL format for easier processing.
    # 輸入是彩色圖像（RGB），轉成 PIL Image 以方便處理。
    image = Image.fromarray(frame)

    # 轉灰階
    # Convert the image to grayscale to reduce input complexity.
    # 將影像轉為灰階，降低輸入維度與計算量。
    image = image.convert('L')

    # resize 成 84x84
    # Resize the image to a standard 84x84 shape, as per DQN convention.
    # 依照 DQN 的慣例將影像統一縮放至 84x84。
    image = image.resize((84, 84), Image.Resampling.BILINEAR)  # or NEAREST, or LANCZOS

    # 轉回 numpy 並正規化
    # Convert back to NumPy and normalize pixel values to [0, 1].
    # 轉回 NumPy 格式並將像素值標準化到 [0, 1]。
    frame = np.asarray(image, dtype=np.float32) / 255.0

    return frame


def stack_frames(stacked_frames, state, is_new_episode):
    # 預處理目前影格
    frame = preprocess_frame(state)

    if is_new_episode or stacked_frames is None:
        # If it's a new episode or no previous frames, initialize with 4 identical frames
        # 若是新的一集或是尚未初始化，則用目前影格複製 4 次形成初始堆疊
        stacked_frames = deque([frame]*4, maxlen=4)
    else:
        # 否則把新影格加入到堆疊中，自動捨棄最舊的
        stacked_frames.append(frame)

    # Stack the 4 frames along the first dimension: shape becomes (4, 84, 84)
    # 沿著第一維（channel）堆疊成 4 通道輸入：形狀變成 (4, 84, 84)
    stacked_state = np.stack(stacked_frames, axis=0)

    return stacked_state, stacked_frames

# %%
# 初始化 Breakout 環境 / Initialize the Breakout environment
env = SpaceShipEnv()
num_actions = len(env.action_space)

# 建立策略網路與目標網路 / Create policy and target networks
policy_net = DQN(num_actions).to(device)
target_net = DQN(num_actions).to(device)
target_net.load_state_dict(policy_net.state_dict())  # 初始時讓目標網路等於策略網路
target_net.eval()

optimizer = optim.Adam(policy_net.parameters(), lr=lr)
memory = ReplayMemory(memory_capacity)

# 載入模型（若有）
if os.path.exists('checkpoint.pth'):
    checkpoint = torch.load('checkpoint.pth', map_location=device)
    policy_net.load_state_dict(checkpoint['policy_net'])
    target_net.load_state_dict(checkpoint['target_net'])
    optimizer.load_state_dict(checkpoint['optimizer'])
    start_episode = checkpoint['episode'] + 1
    total_steps = checkpoint['total_steps']
    best_score = checkpoint['best_score']
    epsilon = checkpoint['epsilon']
    reward_history = checkpoint['reward_history']
    score_history = checkpoint['score_history']
    print(f"Loaded checkpoint from episode {start_episode}, best score: {best_score:.2f}, epsilon={epsilon:.3f}")
else:
    start_episode = 0
    total_steps = 0
    best_score = float('-inf')
    epsilon = epsilon_start
    reward_history = []
    score_history = []


# 訓練迴圈 / Training loop
# 每次可以訓練個100步(根據自己的設備與時間調整)，然後下一次都再接續上次的訓練模型接續往下訓練
# You can train for 100 steps each time (adjust according to your own equipment and time), 
# and then continue training from the last training model next time.
for episode in range(start_episode, 3000): # last time = 3200
    state = env.reset()
    state, stacked_frames = stack_frames(None, state, True)
    total_reward, done = 0, False

    while not done:
        # ε-greedy 策略：隨機選擇動作或從模型中選擇 / Epsilon-greedy action selection
        if random.random() < epsilon:
            action = random.choice(env.action_space)
        else:
            with torch.no_grad():
                state_tensor = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
                action = policy_net(state_tensor).argmax(dim=1).item()

        # 執行動作 / Perform action
        next_state, reward, done_, score = env.step(action)
        done = done_
        total_reward += reward

        next_state, stacked_frames = stack_frames(stacked_frames, next_state, False)
        memory.push(state, action, reward, next_state, done)
        state = next_state

        # 訓練模型 / Train the model from memory
        if len(memory) >= batch_size:
            states, actions, rewards, next_states, dones = memory.sample(batch_size)

            with torch.no_grad():
                target_q = rewards + gamma * target_net(next_states).max(1)[0] * (1 - dones)

            current_q = policy_net(states).gather(1, actions.unsqueeze(1)).squeeze(1)
            loss = F.mse_loss(current_q, target_q)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        # 更新 target 網路 / Periodically update target net
        total_steps += 1
        if total_steps % target_update_freq == 0:
            target_net.load_state_dict(policy_net.state_dict())

    # 更新 epsilon 並紀錄統計資料 / Decay epsilon and log results
    epsilon = max(epsilon_end, epsilon * epsilon_decay)
    reward_history.append(total_reward)
    score_history.append(score)

    print(f"Episode {episode + 1:3d}, Reward: {total_reward:7.2f}, Score: {score:4d}, Epsilon: {epsilon:5.3f}")

    # 儲存模型（若比目前最佳分數更好，或每 50 回合）
    if (episode + 1) % 50 == 0 or score > best_score:
        best_score = max(best_score, score)

        torch.save({
            'policy_net': policy_net.state_dict(),
            'target_net': target_net.state_dict(),
            'optimizer': optimizer.state_dict(),
            'epsilon': epsilon,
            'episode': episode,
            'total_steps': total_steps,
            'best_score': best_score,
            'reward_history': reward_history,
            'score_history': score_history,
        }, 'checkpoint.pth')

        print(f"Checkpoint saved at episode {episode + 1}, best score: {best_score:.2f}")

env.close()
# Out:
# C:\Users\laimm\AppData\Local\Temp\ipykernel_2020\1349279644.py:16: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load('checkpoint.pth', map_location=device)
# Loaded checkpoint from episode 2000, best score: 4714.00, epsilon=0.135
# Episode 2001, Reward:  633.10, Score: 2588, Epsilon: 0.135
# Episode 2002, Reward:  605.00, Score: 2230, Epsilon: 0.135
# Episode 2003, Reward:  589.40, Score: 2328, Epsilon: 0.135
# Episode 2004, Reward:  399.60, Score: 1560, Epsilon: 0.135
# Episode 2005, Reward:  270.60, Score: 1050, Epsilon: 0.135
# Episode 2006, Reward:  250.65, Score: 1148, Epsilon: 0.134
# Episode 2007, Reward:  150.35, Score:  626, Epsilon: 0.134
# Episode 2008, Reward:  281.15, Score: 1188, Epsilon: 0.134
# Episode 2009, Reward:  310.70, Score: 1230, Epsilon: 0.134
# Episode 2010, Reward:  416.85, Score: 1650, Epsilon: 0.134
# Episode 2011, Reward:  274.00, Score: 1072, Epsilon: 0.134
# Episode 2012, Reward:  484.75, Score: 1980, Epsilon: 0.134
# Episode 2013, Reward:  387.85, Score: 1654, Epsilon: 0.133
# Episode 2014, Reward:  333.55, Score: 1428, Epsilon: 0.133
# Episode 2015, Reward:  216.00, Score:  926, Epsilon: 0.133
# Episode 2016, Reward:  501.95, Score: 1978, Epsilon: 0.133
# Episode 2017, Reward:  145.80, Score:  618, Epsilon: 0.133
# Episode 2018, Reward:  704.30, Score: 2678, Epsilon: 0.133
# Episode 2019, Reward:  280.20, Score: 1116, Epsilon: 0.133
# Episode 2020, Reward:  393.25, Score: 1640, Epsilon: 0.133
# Episode 2021, Reward:  110.95, Score:  528, Epsilon: 0.132
# Episode 2022, Reward:  322.00, Score: 1180, Epsilon: 0.132
# Episode 2023, Reward:  543.30, Score: 2012, Epsilon: 0.132
# Episode 2024, Reward:  233.90, Score:  968, Epsilon: 0.132
# Episode 2025, Reward:  248.50, Score:  920, Epsilon: 0.132
# Episode 2026, Reward:  391.40, Score: 1534, Epsilon: 0.132
# Episode 2027, Reward:  304.40, Score: 1154, Epsilon: 0.132
# Episode 2028, Reward:  311.40, Score: 1338, Epsilon: 0.131
# Episode 2029, Reward:  184.05, Score:  768, Epsilon: 0.131
# Episode 2030, Reward:  834.35, Score: 3406, Epsilon: 0.131
# Episode 2031, Reward:  329.80, Score: 1356, Epsilon: 0.131
# Episode 2032, Reward:  406.90, Score: 1678, Epsilon: 0.131
# Episode 2033, Reward:  146.90, Score:  636, Epsilon: 0.131
# Episode 2034, Reward:  378.30, Score: 1418, Epsilon: 0.131
# Episode 2035, Reward:  247.75, Score: 1082, Epsilon: 0.131
# Episode 2036, Reward:  194.25, Score:  796, Epsilon: 0.130
# Episode 2037, Reward:  276.70, Score: 1044, Epsilon: 0.130
# Episode 2038, Reward:  642.90, Score: 2454, Epsilon: 0.130
# Episode 2039, Reward:  859.75, Score: 3038, Epsilon: 0.130
# Episode 2040, Reward:  145.00, Score:  528, Epsilon: 0.130
# Episode 2041, Reward:  787.40, Score: 2782, Epsilon: 0.130
# Episode 2042, Reward:  252.40, Score: 1054, Epsilon: 0.130
# Episode 2043, Reward:  284.95, Score: 1224, Epsilon: 0.130
# Episode 2044, Reward:  282.90, Score: 1028, Epsilon: 0.129
# Episode 2045, Reward:  199.15, Score:  798, Epsilon: 0.129
# Episode 2046, Reward:  571.45, Score: 2146, Epsilon: 0.129
# Episode 2047, Reward:  117.65, Score:  594, Epsilon: 0.129
# Episode 2048, Reward:   65.05, Score:  362, Epsilon: 0.129
# Episode 2049, Reward:  394.85, Score: 1508, Epsilon: 0.129
# Episode 2050, Reward:  756.15, Score: 2704, Epsilon: 0.129
# Checkpoint saved at episode 2050, best score: 4714.00
# Episode 2051, Reward:  580.70, Score: 1998, Epsilon: 0.128
# Episode 2052, Reward:  738.85, Score: 2800, Epsilon: 0.128
# Episode 2053, Reward:  513.95, Score: 2110, Epsilon: 0.128
# Episode 2054, Reward:  838.60, Score: 3074, Epsilon: 0.128
# Episode 2055, Reward:  546.95, Score: 2086, Epsilon: 0.128
# Episode 2056, Reward: 1144.35, Score: 4350, Epsilon: 0.128
# Episode 2057, Reward:  176.00, Score:  704, Epsilon: 0.128
# Episode 2058, Reward:  446.25, Score: 1546, Epsilon: 0.128
# Episode 2059, Reward:  512.30, Score: 2196, Epsilon: 0.127
# Episode 2060, Reward:  387.75, Score: 1582, Epsilon: 0.127
# Episode 2061, Reward:  206.45, Score:  690, Epsilon: 0.127
# Episode 2062, Reward:  695.65, Score: 2438, Epsilon: 0.127
# Episode 2063, Reward:  715.05, Score: 2724, Epsilon: 0.127
# Episode 2064, Reward: 1981.60, Score: 7448, Epsilon: 0.127
# Checkpoint saved at episode 2064, best score: 7448.00
# Episode 2065, Reward:  362.10, Score: 1452, Epsilon: 0.127
# Episode 2066, Reward:  298.15, Score: 1386, Epsilon: 0.127
# Episode 2067, Reward:  181.10, Score:  828, Epsilon: 0.126
# Episode 2068, Reward:  475.95, Score: 1960, Epsilon: 0.126
# Episode 2069, Reward:  299.45, Score: 1268, Epsilon: 0.126
# Episode 2070, Reward:  838.40, Score: 2964, Epsilon: 0.126
# Episode 2071, Reward:  354.15, Score: 1352, Epsilon: 0.126
# Episode 2072, Reward:  509.45, Score: 2102, Epsilon: 0.126
# Episode 2073, Reward: 1277.95, Score: 4736, Epsilon: 0.126
# Episode 2074, Reward:  158.15, Score:  714, Epsilon: 0.126
# Episode 2075, Reward:  720.15, Score: 2896, Epsilon: 0.125
# Episode 2076, Reward:  578.85, Score: 2104, Epsilon: 0.125
# Episode 2077, Reward:  413.25, Score: 1688, Epsilon: 0.125
# Episode 2078, Reward:  776.80, Score: 3074, Epsilon: 0.125
# Episode 2079, Reward:  380.50, Score: 1642, Epsilon: 0.125
# Episode 2080, Reward: 1502.75, Score: 5708, Epsilon: 0.125
# Episode 2081, Reward:  545.05, Score: 1980, Epsilon: 0.125
# Episode 2082, Reward:  350.35, Score: 1342, Epsilon: 0.125
# Episode 2083, Reward:  575.75, Score: 2152, Epsilon: 0.124
# Episode 2084, Reward:  582.00, Score: 2152, Epsilon: 0.124
# Episode 2085, Reward:  166.55, Score:  832, Epsilon: 0.124
# Episode 2086, Reward:  175.00, Score:  610, Epsilon: 0.124
# Episode 2087, Reward:  531.70, Score: 1968, Epsilon: 0.124
# Episode 2088, Reward:  356.75, Score: 1490, Epsilon: 0.124
# Episode 2089, Reward:  399.10, Score: 1598, Epsilon: 0.124
# Episode 2090, Reward:  376.05, Score: 1612, Epsilon: 0.124
# Episode 2091, Reward: 1738.60, Score: 6364, Epsilon: 0.123
# Episode 2092, Reward:  279.15, Score: 1140, Epsilon: 0.123
# Episode 2093, Reward:  247.15, Score:  908, Epsilon: 0.123
# Episode 2094, Reward:   77.00, Score:  388, Epsilon: 0.123
# Episode 2095, Reward:  355.65, Score: 1498, Epsilon: 0.123
# Episode 2096, Reward:  155.55, Score:  644, Epsilon: 0.123
# Episode 2097, Reward:  384.40, Score: 1434, Epsilon: 0.123
# Episode 2098, Reward:  723.05, Score: 2704, Epsilon: 0.123
# Episode 2099, Reward:  630.35, Score: 2356, Epsilon: 0.122
# Episode 2100, Reward: 1180.45, Score: 4382, Epsilon: 0.122
# Checkpoint saved at episode 2100, best score: 7448.00
# Episode 2101, Reward:  268.55, Score: 1030, Epsilon: 0.122
# Episode 2102, Reward:  558.35, Score: 2182, Epsilon: 0.122
# Episode 2103, Reward:  709.60, Score: 2900, Epsilon: 0.122
# Episode 2104, Reward:  286.50, Score: 1044, Epsilon: 0.122
# Episode 2105, Reward:  425.90, Score: 1564, Epsilon: 0.122
# Episode 2106, Reward:  805.40, Score: 3248, Epsilon: 0.122
# Episode 2107, Reward:  471.40, Score: 1582, Epsilon: 0.121
# Episode 2108, Reward: 1473.00, Score: 5776, Epsilon: 0.121
# Episode 2109, Reward:  379.25, Score: 1490, Epsilon: 0.121
# Episode 2110, Reward:  249.90, Score: 1112, Epsilon: 0.121
# Episode 2111, Reward:  190.80, Score:  866, Epsilon: 0.121
# Episode 2112, Reward:  331.45, Score: 1460, Epsilon: 0.121
# Episode 2113, Reward:  283.05, Score: 1098, Epsilon: 0.121
# Episode 2114, Reward:  385.15, Score: 1420, Epsilon: 0.121
# Episode 2115, Reward:  204.05, Score:  784, Epsilon: 0.121
# Episode 2116, Reward: 1096.30, Score: 4314, Epsilon: 0.120
# Episode 2117, Reward: 1409.35, Score: 5282, Epsilon: 0.120
# Episode 2118, Reward:  267.05, Score: 1108, Epsilon: 0.120
# Episode 2119, Reward:  498.05, Score: 1914, Epsilon: 0.120
# Episode 2120, Reward:  404.65, Score: 1756, Epsilon: 0.120
# Episode 2121, Reward:  345.75, Score: 1338, Epsilon: 0.120
# Episode 2122, Reward:  438.30, Score: 1752, Epsilon: 0.120
# Episode 2123, Reward:  100.10, Score:  510, Epsilon: 0.120
# Episode 2124, Reward:  704.40, Score: 2702, Epsilon: 0.119
# Episode 2125, Reward:  259.05, Score: 1008, Epsilon: 0.119
# Episode 2126, Reward:  804.15, Score: 3208, Epsilon: 0.119
# Episode 2127, Reward:  739.60, Score: 2856, Epsilon: 0.119
# Episode 2128, Reward:  222.05, Score: 1028, Epsilon: 0.119
# Episode 2129, Reward:  447.70, Score: 1716, Epsilon: 0.119
# Episode 2130, Reward:  655.75, Score: 2732, Epsilon: 0.119
# Episode 2131, Reward:  498.20, Score: 2312, Epsilon: 0.119
# Episode 2132, Reward:  380.20, Score: 1410, Epsilon: 0.118
# Episode 2133, Reward:  434.80, Score: 1790, Epsilon: 0.118
# Episode 2134, Reward:  511.30, Score: 1854, Epsilon: 0.118
# Episode 2135, Reward:  517.80, Score: 2064, Epsilon: 0.118
# Episode 2136, Reward: 1125.45, Score: 4356, Epsilon: 0.118
# Episode 2137, Reward:  512.60, Score: 1892, Epsilon: 0.118
# Episode 2138, Reward:  491.40, Score: 1880, Epsilon: 0.118
# Episode 2139, Reward:  407.85, Score: 1560, Epsilon: 0.118
# Episode 2140, Reward:  257.35, Score: 1240, Epsilon: 0.118
# Episode 2141, Reward:  451.20, Score: 1700, Epsilon: 0.117
# Episode 2142, Reward:  128.00, Score:  694, Epsilon: 0.117
# Episode 2143, Reward:  591.10, Score: 2300, Epsilon: 0.117
# Episode 2144, Reward:  524.20, Score: 2092, Epsilon: 0.117
# Episode 2145, Reward:  889.10, Score: 3424, Epsilon: 0.117
# Episode 2146, Reward:  697.25, Score: 2632, Epsilon: 0.117
# Episode 2147, Reward:  492.50, Score: 1912, Epsilon: 0.117
# Episode 2148, Reward:  578.30, Score: 2238, Epsilon: 0.117
# Episode 2149, Reward:  718.30, Score: 3020, Epsilon: 0.116
# Episode 2150, Reward:  102.80, Score:  502, Epsilon: 0.116
# Checkpoint saved at episode 2150, best score: 7448.00
# Episode 2151, Reward:  163.30, Score:  800, Epsilon: 0.116
# Episode 2152, Reward:  181.80, Score:  800, Epsilon: 0.116
# Episode 2153, Reward:  504.75, Score: 1984, Epsilon: 0.116
# Episode 2154, Reward:   55.95, Score:  340, Epsilon: 0.116
# Episode 2155, Reward:  328.35, Score: 1340, Epsilon: 0.116
# Episode 2156, Reward:  585.80, Score: 2398, Epsilon: 0.116
# Episode 2157, Reward:  595.15, Score: 2334, Epsilon: 0.116
# Episode 2158, Reward:  999.90, Score: 3592, Epsilon: 0.115
# Episode 2159, Reward:  534.55, Score: 1856, Epsilon: 0.115
# Episode 2160, Reward:  686.25, Score: 2804, Epsilon: 0.115
# Episode 2161, Reward:  355.20, Score: 1436, Epsilon: 0.115
# Episode 2162, Reward: 1467.60, Score: 5746, Epsilon: 0.115
# Episode 2163, Reward: 1226.25, Score: 4574, Epsilon: 0.115
# Episode 2164, Reward:  507.40, Score: 2042, Epsilon: 0.115
# Episode 2165, Reward:  541.55, Score: 2366, Epsilon: 0.115
# Episode 2166, Reward:  337.85, Score: 1216, Epsilon: 0.115
# Episode 2167, Reward:  136.10, Score:  588, Epsilon: 0.114
# Episode 2168, Reward:  806.20, Score: 3048, Epsilon: 0.114
# Episode 2169, Reward:  378.15, Score: 1494, Epsilon: 0.114
# Episode 2170, Reward:  683.90, Score: 2774, Epsilon: 0.114
# Episode 2171, Reward:  517.85, Score: 1952, Epsilon: 0.114
# Episode 2172, Reward:  241.55, Score:  900, Epsilon: 0.114
# Episode 2173, Reward:  388.85, Score: 1588, Epsilon: 0.114
# Episode 2174, Reward:  257.15, Score: 1046, Epsilon: 0.114
# Episode 2175, Reward:   32.60, Score:  252, Epsilon: 0.113
# Episode 2176, Reward: 1498.35, Score: 5922, Epsilon: 0.113
# Episode 2177, Reward:  523.35, Score: 2162, Epsilon: 0.113
# Episode 2178, Reward:  800.40, Score: 3492, Epsilon: 0.113
# Episode 2179, Reward:  232.40, Score: 1024, Epsilon: 0.113
# Episode 2180, Reward:  390.35, Score: 1540, Epsilon: 0.113
# Episode 2181, Reward:  209.75, Score: 1002, Epsilon: 0.113
# Episode 2182, Reward:  687.20, Score: 2544, Epsilon: 0.113
# Episode 2183, Reward:  558.50, Score: 2288, Epsilon: 0.113
# Episode 2184, Reward:  401.55, Score: 1650, Epsilon: 0.112
# Episode 2185, Reward:  681.05, Score: 2654, Epsilon: 0.112
# Episode 2186, Reward:  508.80, Score: 2134, Epsilon: 0.112
# Episode 2187, Reward:  139.60, Score:  596, Epsilon: 0.112
# Episode 2188, Reward:  577.70, Score: 2152, Epsilon: 0.112
# Episode 2189, Reward:  805.70, Score: 3016, Epsilon: 0.112
# Episode 2190, Reward:  474.20, Score: 1968, Epsilon: 0.112
# Episode 2191, Reward:  461.55, Score: 1662, Epsilon: 0.112
# Episode 2192, Reward:  517.80, Score: 2298, Epsilon: 0.112
# Episode 2193, Reward:  950.35, Score: 3952, Epsilon: 0.111
# Episode 2194, Reward:  364.25, Score: 1478, Epsilon: 0.111
# Episode 2195, Reward:  981.85, Score: 3628, Epsilon: 0.111
# Episode 2196, Reward:  272.40, Score: 1180, Epsilon: 0.111
# Episode 2197, Reward:  311.75, Score: 1100, Epsilon: 0.111
# Episode 2198, Reward:  736.35, Score: 3084, Epsilon: 0.111
# Episode 2199, Reward:  304.50, Score: 1222, Epsilon: 0.111
# Episode 2200, Reward:  100.50, Score:  440, Epsilon: 0.111
# Checkpoint saved at episode 2200, best score: 7448.00
# Episode 2201, Reward:  376.20, Score: 1540, Epsilon: 0.111
# Episode 2202, Reward:  159.35, Score:  612, Epsilon: 0.110
# Episode 2203, Reward:  514.10, Score: 2102, Epsilon: 0.110
# Episode 2204, Reward:  299.55, Score: 1180, Epsilon: 0.110
# Episode 2205, Reward:  114.45, Score:  458, Epsilon: 0.110
# Episode 2206, Reward:  112.75, Score:  446, Epsilon: 0.110
# Episode 2207, Reward:  409.00, Score: 1734, Epsilon: 0.110
# Episode 2208, Reward:  471.05, Score: 1884, Epsilon: 0.110
# Episode 2209, Reward:  215.75, Score:  838, Epsilon: 0.110
# Episode 2210, Reward:  677.30, Score: 2752, Epsilon: 0.110
# Episode 2211, Reward:  954.75, Score: 3638, Epsilon: 0.109
# Episode 2212, Reward:  627.00, Score: 2546, Epsilon: 0.109
# Episode 2213, Reward:  486.40, Score: 2064, Epsilon: 0.109
# Episode 2214, Reward:   75.65, Score:  360, Epsilon: 0.109
# Episode 2215, Reward:  437.60, Score: 1816, Epsilon: 0.109
# Episode 2216, Reward: 1037.85, Score: 4112, Epsilon: 0.109
# Episode 2217, Reward:  377.15, Score: 1576, Epsilon: 0.109
# Episode 2218, Reward:  448.30, Score: 2008, Epsilon: 0.109
# Episode 2219, Reward:  618.90, Score: 2448, Epsilon: 0.109
# Episode 2220, Reward:  373.90, Score: 1432, Epsilon: 0.108
# Episode 2221, Reward: 1399.35, Score: 5824, Epsilon: 0.108
# Episode 2222, Reward:  329.10, Score: 1496, Epsilon: 0.108
# Episode 2223, Reward:  344.30, Score: 1500, Epsilon: 0.108
# Episode 2224, Reward:  165.10, Score:  872, Epsilon: 0.108
# Episode 2225, Reward:   61.10, Score:  398, Epsilon: 0.108
# Episode 2226, Reward:   75.45, Score:  500, Epsilon: 0.108
# Episode 2227, Reward:  257.55, Score: 1074, Epsilon: 0.108
# Episode 2228, Reward:  428.80, Score: 1876, Epsilon: 0.108
# Episode 2229, Reward:  184.90, Score:  704, Epsilon: 0.108
# Episode 2230, Reward:  893.60, Score: 3892, Epsilon: 0.107
# Episode 2231, Reward:  554.65, Score: 2188, Epsilon: 0.107
# Episode 2232, Reward:  253.65, Score: 1170, Epsilon: 0.107
# Episode 2233, Reward:  347.05, Score: 1462, Epsilon: 0.107
# Episode 2234, Reward:  590.50, Score: 2456, Epsilon: 0.107
# Episode 2235, Reward:  469.60, Score: 1970, Epsilon: 0.107
# Episode 2236, Reward:  535.20, Score: 1990, Epsilon: 0.107
# Episode 2237, Reward:  292.25, Score: 1162, Epsilon: 0.107
# Episode 2238, Reward:  289.65, Score: 1288, Epsilon: 0.107
# Episode 2239, Reward:  872.35, Score: 3560, Epsilon: 0.106
# Episode 2240, Reward: 1525.30, Score: 6182, Epsilon: 0.106
# Episode 2241, Reward: 1144.50, Score: 4744, Epsilon: 0.106
# Episode 2242, Reward:  270.05, Score:  972, Epsilon: 0.106
# Episode 2243, Reward:  240.65, Score: 1068, Epsilon: 0.106
# Episode 2244, Reward:  297.65, Score: 1246, Epsilon: 0.106
# Episode 2245, Reward:  621.90, Score: 2490, Epsilon: 0.106
# Episode 2246, Reward:  304.65, Score: 1252, Epsilon: 0.106
# Episode 2247, Reward:  400.95, Score: 1530, Epsilon: 0.106
# Episode 2248, Reward:  788.50, Score: 3108, Epsilon: 0.105
# Episode 2249, Reward:  250.35, Score: 1200, Epsilon: 0.105
# Episode 2250, Reward: 1650.90, Score: 6318, Epsilon: 0.105
# Checkpoint saved at episode 2250, best score: 7448.00
# Episode 2251, Reward:  471.60, Score: 1840, Epsilon: 0.105
# Episode 2252, Reward:  351.45, Score: 1448, Epsilon: 0.105
# Episode 2253, Reward:  441.60, Score: 1862, Epsilon: 0.105
# Episode 2254, Reward:  612.45, Score: 2576, Epsilon: 0.105
# Episode 2255, Reward:  859.40, Score: 3608, Epsilon: 0.105
# Episode 2256, Reward:  424.60, Score: 1870, Epsilon: 0.105
# Episode 2257, Reward:  687.85, Score: 2986, Epsilon: 0.105
# Episode 2258, Reward:  456.00, Score: 1780, Epsilon: 0.104
# Episode 2259, Reward:  164.00, Score:  830, Epsilon: 0.104
# Episode 2260, Reward:  128.90, Score:  448, Epsilon: 0.104
# Episode 2261, Reward:  264.15, Score: 1204, Epsilon: 0.104
# Episode 2262, Reward:  312.95, Score: 1090, Epsilon: 0.104
# Episode 2263, Reward: 1096.00, Score: 4644, Epsilon: 0.104
# Episode 2264, Reward:  384.10, Score: 1456, Epsilon: 0.104
# Episode 2265, Reward:  192.90, Score:  818, Epsilon: 0.104
# Episode 2266, Reward:  312.65, Score: 1270, Epsilon: 0.104
# Episode 2267, Reward:  405.80, Score: 1574, Epsilon: 0.104
# Episode 2268, Reward:  282.40, Score: 1190, Epsilon: 0.103
# Episode 2269, Reward:  993.25, Score: 3748, Epsilon: 0.103
# Episode 2270, Reward:  579.65, Score: 2440, Epsilon: 0.103
# Episode 2271, Reward:  278.40, Score: 1026, Epsilon: 0.103
# Episode 2272, Reward:  589.70, Score: 2392, Epsilon: 0.103
# Episode 2273, Reward:  396.25, Score: 1730, Epsilon: 0.103
# Episode 2274, Reward:  385.95, Score: 1730, Epsilon: 0.103
# Episode 2275, Reward:  291.95, Score: 1140, Epsilon: 0.103
# Episode 2276, Reward:  836.50, Score: 3262, Epsilon: 0.103
# Episode 2277, Reward:  270.90, Score: 1018, Epsilon: 0.102
# Episode 2278, Reward:  245.00, Score: 1036, Epsilon: 0.102
# Episode 2279, Reward:  853.25, Score: 3224, Epsilon: 0.102
# Episode 2280, Reward:  605.60, Score: 2346, Epsilon: 0.102
# Episode 2281, Reward:  121.30, Score:  500, Epsilon: 0.102
# Episode 2282, Reward:  214.35, Score:  996, Epsilon: 0.102
# Episode 2283, Reward:  261.40, Score: 1128, Epsilon: 0.102
# Episode 2284, Reward:  601.35, Score: 2382, Epsilon: 0.102
# Episode 2285, Reward:  376.00, Score: 1526, Epsilon: 0.102
# Episode 2286, Reward: 1017.30, Score: 4022, Epsilon: 0.102
# Episode 2287, Reward:  905.85, Score: 3588, Epsilon: 0.101
# Episode 2288, Reward:  363.65, Score: 1712, Epsilon: 0.101
# Episode 2289, Reward:  986.00, Score: 3796, Epsilon: 0.101
# Episode 2290, Reward:  259.05, Score: 1116, Epsilon: 0.101
# Episode 2291, Reward:  472.20, Score: 1930, Epsilon: 0.101
# Episode 2292, Reward:   82.15, Score:  342, Epsilon: 0.101
# Episode 2293, Reward:  579.70, Score: 2222, Epsilon: 0.101
# Episode 2294, Reward: 1044.15, Score: 4238, Epsilon: 0.101
# Episode 2295, Reward:  453.10, Score: 1812, Epsilon: 0.101
# Episode 2296, Reward:  597.30, Score: 2584, Epsilon: 0.101
# Episode 2297, Reward:  438.75, Score: 1826, Epsilon: 0.100
# Episode 2298, Reward:  264.95, Score: 1056, Epsilon: 0.100
# Episode 2299, Reward:  308.00, Score: 1218, Epsilon: 0.100
# Episode 2300, Reward:  474.05, Score: 1650, Epsilon: 0.100
# Checkpoint saved at episode 2300, best score: 7448.00
# Episode 2301, Reward:  241.35, Score: 1092, Epsilon: 0.100
# Episode 2302, Reward: 1146.65, Score: 4656, Epsilon: 0.100
# Episode 2303, Reward:   90.20, Score:  456, Epsilon: 0.100
# Episode 2304, Reward:  437.15, Score: 1676, Epsilon: 0.100
# Episode 2305, Reward:  259.60, Score: 1166, Epsilon: 0.100
# Episode 2306, Reward:  357.55, Score: 1452, Epsilon: 0.100
# Episode 2307, Reward:   85.65, Score:  456, Epsilon: 0.099
# Episode 2308, Reward:  244.80, Score: 1210, Epsilon: 0.099
# Episode 2309, Reward:  217.70, Score:  920, Epsilon: 0.099
# Episode 2310, Reward:  298.80, Score: 1254, Epsilon: 0.099
# Episode 2311, Reward:  508.10, Score: 2164, Epsilon: 0.099
# Episode 2312, Reward: 1315.85, Score: 5244, Epsilon: 0.099
# Episode 2313, Reward:  457.80, Score: 2002, Epsilon: 0.099
# Episode 2314, Reward:  308.15, Score: 1306, Epsilon: 0.099
# Episode 2315, Reward:   34.40, Score:  246, Epsilon: 0.099
# Episode 2316, Reward:  412.35, Score: 1766, Epsilon: 0.099
# Episode 2317, Reward:  364.80, Score: 1498, Epsilon: 0.098
# Episode 2318, Reward:  327.35, Score: 1268, Epsilon: 0.098
# Episode 2319, Reward:  541.25, Score: 2258, Epsilon: 0.098
# Episode 2320, Reward:  893.25, Score: 3848, Epsilon: 0.098
# Episode 2321, Reward:  243.85, Score: 1074, Epsilon: 0.098
# Episode 2322, Reward:  111.15, Score:  610, Epsilon: 0.098
# Episode 2323, Reward:  233.10, Score: 1090, Epsilon: 0.098
# Episode 2324, Reward:  300.65, Score: 1236, Epsilon: 0.098
# Episode 2325, Reward:  132.60, Score:  554, Epsilon: 0.098
# Episode 2326, Reward:  523.65, Score: 2140, Epsilon: 0.098
# Episode 2327, Reward:  203.95, Score:  870, Epsilon: 0.097
# Episode 2328, Reward:   75.25, Score:  400, Epsilon: 0.097
# Episode 2329, Reward:  607.10, Score: 2656, Epsilon: 0.097
# Episode 2330, Reward:  224.95, Score:  902, Epsilon: 0.097
# Episode 2331, Reward:  635.45, Score: 2636, Epsilon: 0.097
# Episode 2332, Reward:  733.35, Score: 3136, Epsilon: 0.097
# Episode 2333, Reward:  144.00, Score:  738, Epsilon: 0.097
# Episode 2334, Reward: 1234.25, Score: 5326, Epsilon: 0.097
# Episode 2335, Reward:  172.85, Score:  818, Epsilon: 0.097
# Episode 2336, Reward:   44.70, Score:  246, Epsilon: 0.097
# Episode 2337, Reward:  124.85, Score:  624, Epsilon: 0.097
# Episode 2338, Reward:  267.00, Score: 1076, Epsilon: 0.096
# Episode 2339, Reward:  302.70, Score: 1296, Epsilon: 0.096
# Episode 2340, Reward:  117.60, Score:  690, Epsilon: 0.096
# Episode 2341, Reward: 1686.90, Score: 6718, Epsilon: 0.096
# Episode 2342, Reward:  225.35, Score:  940, Epsilon: 0.096
# Episode 2343, Reward:  312.85, Score: 1418, Epsilon: 0.096
# Episode 2344, Reward:  165.30, Score:  712, Epsilon: 0.096
# Episode 2345, Reward:  258.45, Score: 1098, Epsilon: 0.096
# Episode 2346, Reward:  520.70, Score: 2240, Epsilon: 0.096
# Episode 2347, Reward:  328.30, Score: 1310, Epsilon: 0.096
# Episode 2348, Reward:  208.15, Score:  822, Epsilon: 0.095
# Episode 2349, Reward:   78.75, Score:  398, Epsilon: 0.095
# Episode 2350, Reward:  471.55, Score: 1696, Epsilon: 0.095
# Checkpoint saved at episode 2350, best score: 7448.00
# Episode 2351, Reward:  376.40, Score: 1522, Epsilon: 0.095
# Episode 2352, Reward:  378.10, Score: 1496, Epsilon: 0.095
# Episode 2353, Reward:  332.90, Score: 1310, Epsilon: 0.095
# Episode 2354, Reward:  294.65, Score: 1254, Epsilon: 0.095
# Episode 2355, Reward: 1263.10, Score: 5014, Epsilon: 0.095
# Episode 2356, Reward:  165.80, Score:  792, Epsilon: 0.095
# Episode 2357, Reward:  125.65, Score:  570, Epsilon: 0.095
# Episode 2358, Reward:  417.40, Score: 1708, Epsilon: 0.094
# Episode 2359, Reward:  997.85, Score: 4042, Epsilon: 0.094
# Episode 2360, Reward:  297.30, Score: 1254, Epsilon: 0.094
# Episode 2361, Reward: 1061.20, Score: 3880, Epsilon: 0.094
# Episode 2362, Reward:  225.15, Score: 1086, Epsilon: 0.094
# Episode 2363, Reward:  360.90, Score: 1654, Epsilon: 0.094
# Episode 2364, Reward:  874.55, Score: 3496, Epsilon: 0.094
# Episode 2365, Reward:  192.05, Score:  780, Epsilon: 0.094
# Episode 2366, Reward:  429.25, Score: 1744, Epsilon: 0.094
# Episode 2367, Reward:  420.40, Score: 1666, Epsilon: 0.094
# Episode 2368, Reward:  480.90, Score: 1990, Epsilon: 0.094
# Episode 2369, Reward:  200.10, Score:  962, Epsilon: 0.093
# Episode 2370, Reward:  273.80, Score: 1198, Epsilon: 0.093
# Episode 2371, Reward:  125.80, Score:  436, Epsilon: 0.093
# Episode 2372, Reward:  539.80, Score: 2076, Epsilon: 0.093
# Episode 2373, Reward:  338.70, Score: 1360, Epsilon: 0.093
# Episode 2374, Reward:  138.45, Score:  560, Epsilon: 0.093
# Episode 2375, Reward:   68.60, Score:  316, Epsilon: 0.093
# Episode 2376, Reward:  305.25, Score: 1386, Epsilon: 0.093
# Episode 2377, Reward:  522.75, Score: 2026, Epsilon: 0.093
# Episode 2378, Reward: 1382.40, Score: 5434, Epsilon: 0.093
# Episode 2379, Reward:  397.90, Score: 1862, Epsilon: 0.093
# Episode 2380, Reward:  336.00, Score: 1458, Epsilon: 0.092
# Episode 2381, Reward:  504.05, Score: 2010, Epsilon: 0.092
# Episode 2382, Reward:  716.40, Score: 2836, Epsilon: 0.092
# Episode 2383, Reward:  336.20, Score: 1138, Epsilon: 0.092
# Episode 2384, Reward:  393.05, Score: 1740, Epsilon: 0.092
# Episode 2385, Reward:  244.35, Score:  942, Epsilon: 0.092
# Episode 2386, Reward:  571.35, Score: 2272, Epsilon: 0.092
# Episode 2387, Reward:  305.60, Score: 1388, Epsilon: 0.092
# Episode 2388, Reward:  356.90, Score: 1472, Epsilon: 0.092
# Episode 2389, Reward:  301.30, Score: 1188, Epsilon: 0.092
# Episode 2390, Reward:  553.40, Score: 2458, Epsilon: 0.092
# Episode 2391, Reward:  496.00, Score: 2162, Epsilon: 0.091
# Episode 2392, Reward:  908.80, Score: 3682, Epsilon: 0.091
# Episode 2393, Reward:  645.95, Score: 2804, Epsilon: 0.091
# Episode 2394, Reward:  218.60, Score:  854, Epsilon: 0.091
# Episode 2395, Reward: 1113.10, Score: 4634, Epsilon: 0.091
# Episode 2396, Reward:  205.05, Score: 1002, Epsilon: 0.091
# Episode 2397, Reward:  340.40, Score: 1396, Epsilon: 0.091
# Episode 2398, Reward:  213.15, Score:  920, Epsilon: 0.091
# Episode 2399, Reward:  368.55, Score: 1642, Epsilon: 0.091
# Episode 2400, Reward:  279.45, Score: 1106, Epsilon: 0.091
# Checkpoint saved at episode 2400, best score: 7448.00
# Episode 2401, Reward:  731.60, Score: 3070, Epsilon: 0.091
# Episode 2402, Reward:  417.85, Score: 1908, Epsilon: 0.090
# Episode 2403, Reward:  265.90, Score: 1168, Epsilon: 0.090
# Episode 2404, Reward:  365.05, Score: 1530, Epsilon: 0.090
# Episode 2405, Reward:  311.10, Score: 1158, Epsilon: 0.090
# Episode 2406, Reward:  600.50, Score: 2488, Epsilon: 0.090
# Episode 2407, Reward: 1310.35, Score: 5152, Epsilon: 0.090
# Episode 2408, Reward:  296.95, Score: 1292, Epsilon: 0.090
# Episode 2409, Reward:  306.70, Score: 1098, Epsilon: 0.090
# Episode 2410, Reward:  510.90, Score: 1966, Epsilon: 0.090
# Episode 2411, Reward:  146.25, Score:  626, Epsilon: 0.090
# Episode 2412, Reward:  570.45, Score: 2390, Epsilon: 0.090
# Episode 2413, Reward:  488.65, Score: 2102, Epsilon: 0.089
# Episode 2414, Reward:  465.80, Score: 1948, Epsilon: 0.089
# Episode 2415, Reward:  700.55, Score: 2920, Epsilon: 0.089
# Episode 2416, Reward:  188.20, Score:  772, Epsilon: 0.089
# Episode 2417, Reward:  132.50, Score:  482, Epsilon: 0.089
# Episode 2418, Reward:  239.55, Score: 1040, Epsilon: 0.089
# Episode 2419, Reward:  227.45, Score: 1082, Epsilon: 0.089
# Episode 2420, Reward:  328.05, Score: 1370, Epsilon: 0.089
# Episode 2421, Reward:  359.85, Score: 1448, Epsilon: 0.089
# Episode 2422, Reward:  342.45, Score: 1412, Epsilon: 0.089
# Episode 2423, Reward:  223.85, Score:  934, Epsilon: 0.089
# Episode 2424, Reward:  517.55, Score: 2270, Epsilon: 0.088
# Episode 2425, Reward:  703.25, Score: 2848, Epsilon: 0.088
# Episode 2426, Reward:  655.05, Score: 2700, Epsilon: 0.088
# Episode 2427, Reward:  420.70, Score: 1946, Epsilon: 0.088
# Episode 2428, Reward:  347.95, Score: 1302, Epsilon: 0.088
# Episode 2429, Reward:  379.15, Score: 1456, Epsilon: 0.088
# Episode 2430, Reward:  637.55, Score: 2640, Epsilon: 0.088
# Episode 2431, Reward:  460.90, Score: 1856, Epsilon: 0.088
# Episode 2432, Reward:  166.25, Score:  716, Epsilon: 0.088
# Episode 2433, Reward:  302.10, Score: 1314, Epsilon: 0.088
# Episode 2434, Reward:  449.30, Score: 1796, Epsilon: 0.088
# Episode 2435, Reward:  367.70, Score: 1212, Epsilon: 0.087
# Episode 2436, Reward:  734.90, Score: 2950, Epsilon: 0.087
# Episode 2437, Reward:  184.30, Score:  838, Epsilon: 0.087
# Episode 2438, Reward:  658.75, Score: 2552, Epsilon: 0.087
# Episode 2439, Reward: 1445.65, Score: 5894, Epsilon: 0.087
# Episode 2440, Reward:  324.05, Score: 1390, Epsilon: 0.087
# Episode 2441, Reward:  255.20, Score: 1092, Epsilon: 0.087
# Episode 2442, Reward:  335.20, Score: 1328, Epsilon: 0.087
# Episode 2443, Reward:  839.10, Score: 3224, Epsilon: 0.087
# Episode 2444, Reward:  518.30, Score: 2166, Epsilon: 0.087
# Episode 2445, Reward:  270.10, Score: 1234, Epsilon: 0.087
# Episode 2446, Reward:  175.55, Score:  776, Epsilon: 0.087
# Episode 2447, Reward:  249.75, Score: 1184, Epsilon: 0.086
# Episode 2448, Reward:   81.80, Score:  416, Epsilon: 0.086
# Episode 2449, Reward:  427.65, Score: 1944, Epsilon: 0.086
# Episode 2450, Reward:  715.90, Score: 3062, Epsilon: 0.086
# Checkpoint saved at episode 2450, best score: 7448.00
# Episode 2451, Reward:  147.55, Score:  722, Epsilon: 0.086
# Episode 2452, Reward:  284.95, Score: 1318, Epsilon: 0.086
# Episode 2453, Reward:  360.30, Score: 1634, Epsilon: 0.086
# Episode 2454, Reward:  466.95, Score: 1950, Epsilon: 0.086
# Episode 2455, Reward:  359.30, Score: 1528, Epsilon: 0.086
# Episode 2456, Reward:  308.90, Score: 1260, Epsilon: 0.086
# Episode 2457, Reward:  812.40, Score: 3272, Epsilon: 0.086
# Episode 2458, Reward:  238.45, Score:  992, Epsilon: 0.086
# Episode 2459, Reward:  248.55, Score: 1026, Epsilon: 0.085
# Episode 2460, Reward:  434.40, Score: 1742, Epsilon: 0.085
# Episode 2461, Reward:  579.65, Score: 2136, Epsilon: 0.085
# Episode 2462, Reward:  557.40, Score: 2286, Epsilon: 0.085
# Episode 2463, Reward:  668.50, Score: 2804, Epsilon: 0.085
# Episode 2464, Reward:  168.35, Score:  762, Epsilon: 0.085
# Episode 2465, Reward:  285.55, Score: 1150, Epsilon: 0.085
# Episode 2466, Reward:  501.85, Score: 2022, Epsilon: 0.085
# Episode 2467, Reward:  672.85, Score: 2734, Epsilon: 0.085
# Episode 2468, Reward: 1276.25, Score: 5120, Epsilon: 0.085
# Episode 2469, Reward:  410.05, Score: 1738, Epsilon: 0.085
# Episode 2470, Reward:  453.60, Score: 2044, Epsilon: 0.084
# Episode 2471, Reward:  377.90, Score: 1568, Epsilon: 0.084
# Episode 2472, Reward:  276.00, Score: 1116, Epsilon: 0.084
# Episode 2473, Reward: 1690.25, Score: 6544, Epsilon: 0.084
# Episode 2474, Reward:  148.50, Score:  590, Epsilon: 0.084
# Episode 2475, Reward:  412.25, Score: 1602, Epsilon: 0.084
# Episode 2476, Reward:  624.35, Score: 2554, Epsilon: 0.084
# Episode 2477, Reward:  445.30, Score: 1774, Epsilon: 0.084
# Episode 2478, Reward:  397.45, Score: 1624, Epsilon: 0.084
# Episode 2479, Reward:  538.15, Score: 1978, Epsilon: 0.084
# Episode 2480, Reward:  187.10, Score:  764, Epsilon: 0.084
# Episode 2481, Reward:  294.35, Score: 1264, Epsilon: 0.084
# Episode 2482, Reward:  136.15, Score:  706, Epsilon: 0.083
# Episode 2483, Reward:  317.45, Score: 1504, Epsilon: 0.083
# Episode 2484, Reward:  208.35, Score:  900, Epsilon: 0.083
# Episode 2485, Reward:  393.35, Score: 1660, Epsilon: 0.083
# Episode 2486, Reward:  347.25, Score: 1626, Epsilon: 0.083
# Episode 2487, Reward:  387.90, Score: 1608, Epsilon: 0.083
# Episode 2488, Reward:  383.35, Score: 1552, Epsilon: 0.083
# Episode 2489, Reward:  358.55, Score: 1526, Epsilon: 0.083
# Episode 2490, Reward:  123.50, Score:  696, Epsilon: 0.083
# Episode 2491, Reward:  268.90, Score: 1170, Epsilon: 0.083
# Episode 2492, Reward:  207.65, Score:  846, Epsilon: 0.083
# Episode 2493, Reward:  526.95, Score: 2282, Epsilon: 0.083
# Episode 2494, Reward:  293.50, Score: 1150, Epsilon: 0.082
# Episode 2495, Reward:  273.05, Score: 1144, Epsilon: 0.082
# Episode 2496, Reward:  191.15, Score:  936, Epsilon: 0.082
# Episode 2497, Reward:  340.80, Score: 1438, Epsilon: 0.082
# Episode 2498, Reward:   96.70, Score:  458, Epsilon: 0.082
# Episode 2499, Reward:  775.65, Score: 3040, Epsilon: 0.082
# Episode 2500, Reward:  182.45, Score:  748, Epsilon: 0.082
# Checkpoint saved at episode 2500, best score: 7448.00
# Episode 2501, Reward:  372.05, Score: 1532, Epsilon: 0.082
# Episode 2502, Reward:  345.60, Score: 1460, Epsilon: 0.082
# Episode 2503, Reward:  139.70, Score:  672, Epsilon: 0.082
# Episode 2504, Reward:  585.25, Score: 2446, Epsilon: 0.082
# Episode 2505, Reward:  155.55, Score:  682, Epsilon: 0.082
# Episode 2506, Reward:  555.20, Score: 2334, Epsilon: 0.081
# Episode 2507, Reward:  444.50, Score: 1814, Epsilon: 0.081
# Episode 2508, Reward:  455.95, Score: 1748, Epsilon: 0.081
# Episode 2509, Reward:   62.45, Score:  378, Epsilon: 0.081
# Episode 2510, Reward:  282.90, Score: 1242, Epsilon: 0.081
# Episode 2511, Reward:  355.55, Score: 1296, Epsilon: 0.081
# Episode 2512, Reward:  748.35, Score: 3218, Epsilon: 0.081
# Episode 2513, Reward:  650.45, Score: 2834, Epsilon: 0.081
# Episode 2514, Reward:  110.85, Score:  524, Epsilon: 0.081
# Episode 2515, Reward:   97.00, Score:  536, Epsilon: 0.081
# Episode 2516, Reward:  144.50, Score:  606, Epsilon: 0.081
# Episode 2517, Reward:  256.80, Score: 1258, Epsilon: 0.081
# Episode 2518, Reward:  230.45, Score: 1000, Epsilon: 0.081
# Episode 2519, Reward:  257.00, Score: 1150, Epsilon: 0.080
# Episode 2520, Reward:  424.80, Score: 1902, Epsilon: 0.080
# Episode 2521, Reward:  261.20, Score: 1126, Epsilon: 0.080
# Episode 2522, Reward:  855.80, Score: 3686, Epsilon: 0.080
# Episode 2523, Reward:  447.75, Score: 1998, Epsilon: 0.080
# Episode 2524, Reward:  372.20, Score: 1528, Epsilon: 0.080
# Episode 2525, Reward:  168.65, Score:  800, Epsilon: 0.080
# Episode 2526, Reward: 1032.75, Score: 4276, Epsilon: 0.080
# Episode 2527, Reward:  210.65, Score: 1052, Epsilon: 0.080
# Episode 2528, Reward:  356.95, Score: 1416, Epsilon: 0.080
# Episode 2529, Reward:  729.85, Score: 3194, Epsilon: 0.080
# Episode 2530, Reward:  409.80, Score: 1612, Epsilon: 0.080
# Episode 2531, Reward:  544.40, Score: 2146, Epsilon: 0.079
# Episode 2532, Reward:  507.10, Score: 2290, Epsilon: 0.079
# Episode 2533, Reward:  688.85, Score: 2810, Epsilon: 0.079
# Episode 2534, Reward:  220.65, Score: 1030, Epsilon: 0.079
# Episode 2535, Reward:  124.05, Score:  492, Epsilon: 0.079
# Episode 2536, Reward:  123.15, Score:  690, Epsilon: 0.079
# Episode 2537, Reward:  305.65, Score: 1226, Epsilon: 0.079
# Episode 2538, Reward:  155.95, Score:  638, Epsilon: 0.079
# Episode 2539, Reward:  324.50, Score: 1136, Epsilon: 0.079
# Episode 2540, Reward:  514.50, Score: 2332, Epsilon: 0.079
# Episode 2541, Reward:  765.95, Score: 3208, Epsilon: 0.079
# Episode 2542, Reward:  341.45, Score: 1418, Epsilon: 0.079
# Episode 2543, Reward:  306.60, Score: 1340, Epsilon: 0.079
# Episode 2544, Reward:  250.05, Score: 1076, Epsilon: 0.078
# Episode 2545, Reward:  553.10, Score: 2190, Epsilon: 0.078
# Episode 2546, Reward:  444.45, Score: 1876, Epsilon: 0.078
# Episode 2547, Reward:  153.25, Score:  736, Epsilon: 0.078
# Episode 2548, Reward:   94.05, Score:  478, Epsilon: 0.078
# Episode 2549, Reward:  192.10, Score:  772, Epsilon: 0.078
# Episode 2550, Reward:  201.55, Score:  738, Epsilon: 0.078
# Checkpoint saved at episode 2550, best score: 7448.00
# Episode 2551, Reward:  355.50, Score: 1460, Epsilon: 0.078
# Episode 2552, Reward:  630.50, Score: 2640, Epsilon: 0.078
# Episode 2553, Reward:   93.00, Score:  506, Epsilon: 0.078
# Episode 2554, Reward:  112.15, Score:  600, Epsilon: 0.078
# Episode 2555, Reward:  234.40, Score: 1020, Epsilon: 0.078
# Episode 2556, Reward:  631.55, Score: 2718, Epsilon: 0.078
# Episode 2557, Reward:  239.10, Score:  966, Epsilon: 0.077
# Episode 2558, Reward:  957.75, Score: 4082, Epsilon: 0.077
# Episode 2559, Reward:  104.30, Score:  538, Epsilon: 0.077
# Episode 2560, Reward:  230.60, Score: 1156, Epsilon: 0.077
# Episode 2561, Reward:  175.20, Score:  786, Epsilon: 0.077
# Episode 2562, Reward:  569.10, Score: 2508, Epsilon: 0.077
# Episode 2563, Reward:  270.15, Score: 1130, Epsilon: 0.077
# Episode 2564, Reward:   49.55, Score:  320, Epsilon: 0.077
# Episode 2565, Reward:   98.60, Score:  430, Epsilon: 0.077
# Episode 2566, Reward:  365.90, Score: 1536, Epsilon: 0.077
# Episode 2567, Reward:   70.05, Score:  392, Epsilon: 0.077
# Episode 2568, Reward:   74.05, Score:  420, Epsilon: 0.077
# Episode 2569, Reward:  686.05, Score: 2706, Epsilon: 0.077
# Episode 2570, Reward:  530.80, Score: 2228, Epsilon: 0.076
# Episode 2571, Reward:   95.40, Score:  386, Epsilon: 0.076
# Episode 2572, Reward:  105.95, Score:  488, Epsilon: 0.076
# Episode 2573, Reward:  134.45, Score:  604, Epsilon: 0.076
# Episode 2574, Reward:  417.95, Score: 1878, Epsilon: 0.076
# Episode 2575, Reward:  133.15, Score:  600, Epsilon: 0.076
# Episode 2576, Reward:  351.80, Score: 1514, Epsilon: 0.076
# Episode 2577, Reward:  443.20, Score: 1598, Epsilon: 0.076
# Episode 2578, Reward:  385.50, Score: 1612, Epsilon: 0.076
# Episode 2579, Reward:  335.05, Score: 1544, Epsilon: 0.076
# Episode 2580, Reward:  308.70, Score: 1426, Epsilon: 0.076
# Episode 2581, Reward:  264.00, Score: 1234, Epsilon: 0.076
# Episode 2582, Reward:  350.60, Score: 1486, Epsilon: 0.076
# Episode 2583, Reward:  176.10, Score:  884, Epsilon: 0.075
# Episode 2584, Reward:   46.75, Score:  320, Epsilon: 0.075
# Episode 2585, Reward:  169.30, Score:  808, Epsilon: 0.075
# Episode 2586, Reward:  384.80, Score: 1554, Epsilon: 0.075
# Episode 2587, Reward:  343.35, Score: 1436, Epsilon: 0.075
# Episode 2588, Reward:  545.20, Score: 2586, Epsilon: 0.075
# Episode 2589, Reward:  374.85, Score: 1722, Epsilon: 0.075
# Episode 2590, Reward:  445.95, Score: 1610, Epsilon: 0.075
# Episode 2591, Reward:  311.20, Score: 1360, Epsilon: 0.075
# Episode 2592, Reward:  481.05, Score: 1812, Epsilon: 0.075
# Episode 2593, Reward:  100.25, Score:  592, Epsilon: 0.075
# Episode 2594, Reward:  178.55, Score:  724, Epsilon: 0.075
# Episode 2595, Reward:  618.85, Score: 2808, Epsilon: 0.075
# Episode 2596, Reward:  321.00, Score: 1474, Epsilon: 0.074
# Episode 2597, Reward:  102.75, Score:  542, Epsilon: 0.074
# Episode 2598, Reward:   59.30, Score:  282, Epsilon: 0.074
# Episode 2599, Reward:  172.35, Score:  870, Epsilon: 0.074
# Episode 2600, Reward:  793.70, Score: 2900, Epsilon: 0.074
# Checkpoint saved at episode 2600, best score: 7448.00
# Episode 2601, Reward:  323.55, Score: 1152, Epsilon: 0.074
# Episode 2602, Reward:  369.95, Score: 1320, Epsilon: 0.074
# Episode 2603, Reward:   52.20, Score:  266, Epsilon: 0.074
# Episode 2604, Reward:  390.85, Score: 1484, Epsilon: 0.074
# Episode 2605, Reward:   43.45, Score:  280, Epsilon: 0.074
# Episode 2606, Reward:   71.85, Score:  408, Epsilon: 0.074
# Episode 2607, Reward:  453.85, Score: 2190, Epsilon: 0.074
# Episode 2608, Reward:  386.70, Score: 1532, Epsilon: 0.074
# Episode 2609, Reward:  199.05, Score:  672, Epsilon: 0.074
# Episode 2610, Reward:  214.60, Score:  950, Epsilon: 0.073
# Episode 2611, Reward:  234.00, Score:  930, Epsilon: 0.073
# Episode 2612, Reward:  197.60, Score:  876, Epsilon: 0.073
# Episode 2613, Reward:  102.50, Score:  502, Epsilon: 0.073
# Episode 2614, Reward:  251.70, Score: 1036, Epsilon: 0.073
# Episode 2615, Reward:  604.95, Score: 2278, Epsilon: 0.073
# Episode 2616, Reward:  699.10, Score: 2618, Epsilon: 0.073
# Episode 2617, Reward:  363.50, Score: 1410, Epsilon: 0.073
# Episode 2618, Reward:  218.40, Score:  956, Epsilon: 0.073
# Episode 2619, Reward:  344.25, Score: 1436, Epsilon: 0.073
# Episode 2620, Reward:  226.05, Score: 1068, Epsilon: 0.073
# Episode 2621, Reward:  326.85, Score: 1330, Epsilon: 0.073
# Episode 2622, Reward:  220.90, Score:  968, Epsilon: 0.073
# Episode 2623, Reward:  619.60, Score: 2748, Epsilon: 0.072
# Episode 2624, Reward:  344.65, Score: 1332, Epsilon: 0.072
# Episode 2625, Reward:  149.90, Score:  666, Epsilon: 0.072
# Episode 2626, Reward:  471.30, Score: 1982, Epsilon: 0.072
# Episode 2627, Reward:   91.30, Score:  498, Epsilon: 0.072
# Episode 2628, Reward:  326.90, Score: 1412, Epsilon: 0.072
# Episode 2629, Reward: 1310.05, Score: 5398, Epsilon: 0.072
# Episode 2630, Reward:  573.30, Score: 2180, Epsilon: 0.072
# Episode 2631, Reward:  461.85, Score: 2092, Epsilon: 0.072
# Episode 2632, Reward:  166.15, Score:  694, Epsilon: 0.072
# Episode 2633, Reward:  698.90, Score: 2972, Epsilon: 0.072
# Episode 2634, Reward:  441.10, Score: 2014, Epsilon: 0.072
# Episode 2635, Reward:  189.05, Score:  900, Epsilon: 0.072
# Episode 2636, Reward:  386.60, Score: 1508, Epsilon: 0.072
# Episode 2637, Reward:  218.55, Score:  862, Epsilon: 0.071
# Episode 2638, Reward:   63.65, Score:  304, Epsilon: 0.071
# Episode 2639, Reward:  514.85, Score: 2270, Epsilon: 0.071
# Episode 2640, Reward:  263.55, Score: 1064, Epsilon: 0.071
# Episode 2641, Reward:  422.35, Score: 1634, Epsilon: 0.071
# Episode 2642, Reward:  322.80, Score: 1314, Epsilon: 0.071
# Episode 2643, Reward:  562.65, Score: 2256, Epsilon: 0.071
# Episode 2644, Reward:  285.00, Score: 1298, Epsilon: 0.071
# Episode 2645, Reward:  265.70, Score: 1038, Epsilon: 0.071
# Episode 2646, Reward:  270.00, Score: 1118, Epsilon: 0.071
# Episode 2647, Reward:  700.40, Score: 2998, Epsilon: 0.071
# Episode 2648, Reward:  414.50, Score: 1772, Epsilon: 0.071
# Episode 2649, Reward:  315.15, Score: 1310, Epsilon: 0.071
# Episode 2650, Reward:  418.90, Score: 1714, Epsilon: 0.071
# Checkpoint saved at episode 2650, best score: 7448.00
# Episode 2651, Reward:  645.95, Score: 2478, Epsilon: 0.070
# Episode 2652, Reward:  490.30, Score: 2108, Epsilon: 0.070
# Episode 2653, Reward:  500.25, Score: 2042, Epsilon: 0.070
# Episode 2654, Reward:  460.35, Score: 1932, Epsilon: 0.070
# Episode 2655, Reward:  241.55, Score: 1294, Epsilon: 0.070
# Episode 2656, Reward:  466.75, Score: 2024, Epsilon: 0.070
# Episode 2657, Reward:  194.65, Score:  844, Epsilon: 0.070
# Episode 2658, Reward:  662.50, Score: 2668, Epsilon: 0.070
# Episode 2659, Reward:  245.25, Score: 1094, Epsilon: 0.070
# Episode 2660, Reward:  357.00, Score: 1560, Epsilon: 0.070
# Episode 2661, Reward:  517.35, Score: 2106, Epsilon: 0.070
# Episode 2662, Reward:  805.70, Score: 3362, Epsilon: 0.070
# Episode 2663, Reward:  222.10, Score: 1004, Epsilon: 0.070
# Episode 2664, Reward:  593.75, Score: 2656, Epsilon: 0.070
# Episode 2665, Reward:  395.10, Score: 1732, Epsilon: 0.070
# Episode 2666, Reward:  578.95, Score: 2362, Epsilon: 0.069
# Episode 2667, Reward:  158.10, Score:  710, Epsilon: 0.069
# Episode 2668, Reward:  211.10, Score:  932, Epsilon: 0.069
# Episode 2669, Reward:  763.20, Score: 2914, Epsilon: 0.069
# Episode 2670, Reward:  130.40, Score:  642, Epsilon: 0.069
# Episode 2671, Reward:  260.30, Score: 1200, Epsilon: 0.069
# Episode 2672, Reward:  582.10, Score: 2400, Epsilon: 0.069
# Episode 2673, Reward:  575.80, Score: 2412, Epsilon: 0.069
# Episode 2674, Reward:  366.00, Score: 1568, Epsilon: 0.069
# Episode 2675, Reward:  508.05, Score: 2112, Epsilon: 0.069
# Episode 2676, Reward:  546.30, Score: 2184, Epsilon: 0.069
# Episode 2677, Reward:  534.15, Score: 2022, Epsilon: 0.069
# Episode 2678, Reward:  639.75, Score: 2668, Epsilon: 0.069
# Episode 2679, Reward:  237.80, Score:  972, Epsilon: 0.069
# Episode 2680, Reward:  591.80, Score: 2404, Epsilon: 0.068
# Episode 2681, Reward:  634.60, Score: 2634, Epsilon: 0.068
# Episode 2682, Reward:  656.45, Score: 2616, Epsilon: 0.068
# Episode 2683, Reward:  241.25, Score: 1082, Epsilon: 0.068
# Episode 2684, Reward:   77.55, Score:  520, Epsilon: 0.068
# Episode 2685, Reward:  587.60, Score: 2046, Epsilon: 0.068
# Episode 2686, Reward:  611.45, Score: 2520, Epsilon: 0.068
# Episode 2687, Reward:  244.75, Score: 1010, Epsilon: 0.068
# Episode 2688, Reward:  212.70, Score:  896, Epsilon: 0.068
# Episode 2689, Reward:  353.70, Score: 1460, Epsilon: 0.068
# Episode 2690, Reward:  334.85, Score: 1472, Epsilon: 0.068
# Episode 2691, Reward:  857.20, Score: 3466, Epsilon: 0.068
# Episode 2692, Reward:  447.65, Score: 2054, Epsilon: 0.068
# Episode 2693, Reward:   79.30, Score:  392, Epsilon: 0.068
# Episode 2694, Reward:  977.30, Score: 4142, Epsilon: 0.068
# Episode 2695, Reward:  237.55, Score: 1024, Epsilon: 0.067
# Episode 2696, Reward:  705.15, Score: 2766, Epsilon: 0.067
# Episode 2697, Reward:  425.05, Score: 1796, Epsilon: 0.067
# Episode 2698, Reward:  728.05, Score: 3036, Epsilon: 0.067
# Episode 2699, Reward:  126.75, Score:  558, Epsilon: 0.067
# Episode 2700, Reward:  571.10, Score: 2070, Epsilon: 0.067
# Checkpoint saved at episode 2700, best score: 7448.00
# Episode 2701, Reward:   62.15, Score:  392, Epsilon: 0.067
# Episode 2702, Reward:  247.80, Score: 1024, Epsilon: 0.067
# Episode 2703, Reward:  264.40, Score: 1082, Epsilon: 0.067
# Episode 2704, Reward:  301.00, Score: 1154, Epsilon: 0.067
# Episode 2705, Reward:   79.20, Score:  448, Epsilon: 0.067
# Episode 2706, Reward:  711.70, Score: 2878, Epsilon: 0.067
# Episode 2707, Reward:  324.10, Score: 1348, Epsilon: 0.067
# Episode 2708, Reward:  231.95, Score: 1028, Epsilon: 0.067
# Episode 2709, Reward:  230.75, Score: 1058, Epsilon: 0.067
# Episode 2710, Reward:  362.05, Score: 1374, Epsilon: 0.066
# Episode 2711, Reward:  312.40, Score: 1440, Epsilon: 0.066
# Episode 2712, Reward:  676.30, Score: 2886, Epsilon: 0.066
# Episode 2713, Reward:  517.55, Score: 2170, Epsilon: 0.066
# Episode 2714, Reward:   57.40, Score:  320, Epsilon: 0.066
# Episode 2715, Reward:  322.60, Score: 1438, Epsilon: 0.066
# Episode 2716, Reward:  186.25, Score:  906, Epsilon: 0.066
# Episode 2717, Reward:  783.65, Score: 3280, Epsilon: 0.066
# Episode 2718, Reward:  444.10, Score: 1972, Epsilon: 0.066
# Episode 2719, Reward:  243.50, Score: 1112, Epsilon: 0.066
# Episode 2720, Reward:  471.95, Score: 1798, Epsilon: 0.066
# Episode 2721, Reward:  181.20, Score:  746, Epsilon: 0.066
# Episode 2722, Reward:  780.95, Score: 2960, Epsilon: 0.066
# Episode 2723, Reward:  285.80, Score: 1240, Epsilon: 0.066
# Episode 2724, Reward:  180.45, Score:  796, Epsilon: 0.066
# Episode 2725, Reward: 1039.95, Score: 4494, Epsilon: 0.065
# Episode 2726, Reward:  229.30, Score:  874, Epsilon: 0.065
# Episode 2727, Reward:  528.25, Score: 1890, Epsilon: 0.065
# Episode 2728, Reward:  309.75, Score: 1246, Epsilon: 0.065
# Episode 2729, Reward:  277.85, Score: 1124, Epsilon: 0.065
# Episode 2730, Reward:  761.30, Score: 3034, Epsilon: 0.065
# Episode 2731, Reward: 1383.15, Score: 5458, Epsilon: 0.065
# Episode 2732, Reward:  932.55, Score: 3628, Epsilon: 0.065
# Episode 2733, Reward:  117.00, Score:  588, Epsilon: 0.065
# Episode 2734, Reward:  615.75, Score: 2408, Epsilon: 0.065
# Episode 2735, Reward:  124.95, Score:  604, Epsilon: 0.065
# Episode 2736, Reward:   80.40, Score:  438, Epsilon: 0.065
# Episode 2737, Reward:  554.20, Score: 2298, Epsilon: 0.065
# Episode 2738, Reward:  246.40, Score: 1054, Epsilon: 0.065
# Episode 2739, Reward:  512.25, Score: 2138, Epsilon: 0.065
# Episode 2740, Reward:  215.35, Score:  886, Epsilon: 0.064
# Episode 2741, Reward:  366.40, Score: 1408, Epsilon: 0.064
# Episode 2742, Reward:  268.85, Score: 1236, Epsilon: 0.064
# Episode 2743, Reward:   42.25, Score:  244, Epsilon: 0.064
# Episode 2744, Reward:  417.50, Score: 1748, Epsilon: 0.064
# Episode 2745, Reward:  148.55, Score:  694, Epsilon: 0.064
# Episode 2746, Reward:  518.20, Score: 1992, Epsilon: 0.064
# Episode 2747, Reward:  668.85, Score: 2646, Epsilon: 0.064
# Episode 2748, Reward:  571.75, Score: 2344, Epsilon: 0.064
# Episode 2749, Reward:  428.90, Score: 1830, Epsilon: 0.064
# Episode 2750, Reward:  541.85, Score: 2064, Epsilon: 0.064
# Checkpoint saved at episode 2750, best score: 7448.00
# Episode 2751, Reward:  200.70, Score:  866, Epsilon: 0.064
# Episode 2752, Reward:  137.35, Score:  684, Epsilon: 0.064
# Episode 2753, Reward:  601.60, Score: 2606, Epsilon: 0.064
# Episode 2754, Reward:  376.65, Score: 1780, Epsilon: 0.064
# Episode 2755, Reward:  165.90, Score:  792, Epsilon: 0.064
# Episode 2756, Reward:  209.50, Score:  876, Epsilon: 0.063
# Episode 2757, Reward:   61.15, Score:  266, Epsilon: 0.063
# Episode 2758, Reward:  464.80, Score: 1938, Epsilon: 0.063
# Episode 2759, Reward:  527.50, Score: 2190, Epsilon: 0.063
# Episode 2760, Reward:   72.40, Score:  340, Epsilon: 0.063
# Episode 2761, Reward:  559.65, Score: 2250, Epsilon: 0.063
# Episode 2762, Reward:  243.40, Score: 1042, Epsilon: 0.063
# Episode 2763, Reward:  534.80, Score: 2048, Epsilon: 0.063
# Episode 2764, Reward:  237.40, Score: 1020, Epsilon: 0.063
# Episode 2765, Reward:  236.95, Score: 1020, Epsilon: 0.063
# Episode 2766, Reward:  309.40, Score: 1394, Epsilon: 0.063
# Episode 2767, Reward:  758.10, Score: 3098, Epsilon: 0.063
# Episode 2768, Reward:  470.70, Score: 1988, Epsilon: 0.063
# Episode 2769, Reward: 1036.80, Score: 4102, Epsilon: 0.063
# Episode 2770, Reward: 1243.90, Score: 5066, Epsilon: 0.063
# Episode 2771, Reward:  952.15, Score: 3858, Epsilon: 0.063
# Episode 2772, Reward:  741.50, Score: 2928, Epsilon: 0.062
# Episode 2773, Reward:  813.20, Score: 3436, Epsilon: 0.062
# Episode 2774, Reward:  233.75, Score: 1018, Epsilon: 0.062
# Episode 2775, Reward:  433.35, Score: 1652, Epsilon: 0.062
# Episode 2776, Reward:  296.50, Score: 1254, Epsilon: 0.062
# Episode 2777, Reward:  375.00, Score: 1330, Epsilon: 0.062
# Episode 2778, Reward:  129.90, Score:  612, Epsilon: 0.062
# Episode 2779, Reward:  441.45, Score: 1574, Epsilon: 0.062
# Episode 2780, Reward:   57.35, Score:  368, Epsilon: 0.062
# Episode 2781, Reward:  111.55, Score:  514, Epsilon: 0.062
# Episode 2782, Reward:  215.20, Score:  986, Epsilon: 0.062
# Episode 2783, Reward:  312.40, Score: 1474, Epsilon: 0.062
# Episode 2784, Reward:  209.25, Score:  940, Epsilon: 0.062
# Episode 2785, Reward:  214.00, Score: 1012, Epsilon: 0.062
# Episode 2786, Reward:  193.05, Score:  870, Epsilon: 0.062
# Episode 2787, Reward:  183.05, Score:  872, Epsilon: 0.062
# Episode 2788, Reward:  222.40, Score:  956, Epsilon: 0.061
# Episode 2789, Reward:  414.95, Score: 1730, Epsilon: 0.061
# Episode 2790, Reward:  742.20, Score: 3192, Epsilon: 0.061
# Episode 2791, Reward:  244.15, Score:  906, Epsilon: 0.061
# Episode 2792, Reward:  277.15, Score: 1072, Epsilon: 0.061
# Episode 2793, Reward:  467.55, Score: 1950, Epsilon: 0.061
# Episode 2794, Reward:  145.25, Score:  678, Epsilon: 0.061
# Episode 2795, Reward: 1392.65, Score: 5820, Epsilon: 0.061
# Episode 2796, Reward:  415.20, Score: 1590, Epsilon: 0.061
# Episode 2797, Reward:  486.15, Score: 1920, Epsilon: 0.061
# Episode 2798, Reward:  319.50, Score: 1254, Epsilon: 0.061
# Episode 2799, Reward:  463.05, Score: 1930, Epsilon: 0.061
# Episode 2800, Reward:  599.65, Score: 2542, Epsilon: 0.061
# Checkpoint saved at episode 2800, best score: 7448.00
# Episode 2801, Reward:   53.20, Score:  272, Epsilon: 0.061
# Episode 2802, Reward:  147.60, Score:  552, Epsilon: 0.061
# Episode 2803, Reward:  265.25, Score: 1130, Epsilon: 0.061
# Episode 2804, Reward:  326.50, Score: 1268, Epsilon: 0.060
# Episode 2805, Reward: 1123.75, Score: 4856, Epsilon: 0.060
# Episode 2806, Reward:  357.95, Score: 1576, Epsilon: 0.060
# Episode 2807, Reward:   45.70, Score:  290, Epsilon: 0.060
# Episode 2808, Reward:  639.00, Score: 2688, Epsilon: 0.060
# Episode 2809, Reward:  225.30, Score:  994, Epsilon: 0.060
# Episode 2810, Reward:  377.20, Score: 1918, Epsilon: 0.060
# Episode 2811, Reward: 1048.35, Score: 4028, Epsilon: 0.060
# Episode 2812, Reward:  402.75, Score: 1604, Epsilon: 0.060
# Episode 2813, Reward:  630.35, Score: 2446, Epsilon: 0.060
# Episode 2814, Reward:  229.55, Score: 1060, Epsilon: 0.060
# Episode 2815, Reward: 1082.50, Score: 4372, Epsilon: 0.060
# Episode 2816, Reward:  970.10, Score: 4224, Epsilon: 0.060
# Episode 2817, Reward:  173.55, Score:  786, Epsilon: 0.060
# Episode 2818, Reward: 1687.70, Score: 6714, Epsilon: 0.060
# Episode 2819, Reward:  269.60, Score: 1032, Epsilon: 0.060
# Episode 2820, Reward:  347.75, Score: 1314, Epsilon: 0.060
# Episode 2821, Reward: 1404.35, Score: 5964, Epsilon: 0.059
# Episode 2822, Reward:  314.00, Score: 1406, Epsilon: 0.059
# Episode 2823, Reward:  685.00, Score: 3006, Epsilon: 0.059
# Episode 2824, Reward:  962.05, Score: 3666, Epsilon: 0.059
# Episode 2825, Reward:  446.00, Score: 1696, Epsilon: 0.059
# Episode 2826, Reward:  376.60, Score: 1584, Epsilon: 0.059
# Episode 2827, Reward:  218.55, Score:  892, Epsilon: 0.059
# Episode 2828, Reward:   83.75, Score:  428, Epsilon: 0.059
# Episode 2829, Reward:  407.80, Score: 1608, Epsilon: 0.059
# Episode 2830, Reward: 1408.55, Score: 5372, Epsilon: 0.059
# Episode 2831, Reward:  298.30, Score: 1264, Epsilon: 0.059
# Episode 2832, Reward: 1190.10, Score: 4824, Epsilon: 0.059
# Episode 2833, Reward:  222.80, Score: 1006, Epsilon: 0.059
# Episode 2834, Reward:  474.00, Score: 2086, Epsilon: 0.059
# Episode 2835, Reward:  471.30, Score: 1980, Epsilon: 0.059
# Episode 2836, Reward:  436.40, Score: 1812, Epsilon: 0.059
# Episode 2837, Reward:  570.60, Score: 2378, Epsilon: 0.059
# Episode 2838, Reward:  407.00, Score: 1658, Epsilon: 0.058
# Episode 2839, Reward:  276.50, Score: 1038, Epsilon: 0.058
# Episode 2840, Reward:  524.15, Score: 2218, Epsilon: 0.058
# Episode 2841, Reward:  601.70, Score: 2248, Epsilon: 0.058
# Episode 2842, Reward:  338.20, Score: 1366, Epsilon: 0.058
# Episode 2843, Reward: 1689.65, Score: 6786, Epsilon: 0.058
# Episode 2844, Reward:  813.30, Score: 3354, Epsilon: 0.058
# Episode 2845, Reward:  146.20, Score:  622, Epsilon: 0.058
# Episode 2846, Reward:  380.00, Score: 1406, Epsilon: 0.058
# Episode 2847, Reward: 1383.05, Score: 5188, Epsilon: 0.058
# Episode 2848, Reward:  485.90, Score: 2068, Epsilon: 0.058
# Episode 2849, Reward:  230.90, Score: 1112, Epsilon: 0.058
# Episode 2850, Reward:  569.25, Score: 2336, Epsilon: 0.058
# Checkpoint saved at episode 2850, best score: 7448.00
# Episode 2851, Reward:  256.05, Score: 1140, Epsilon: 0.058
# Episode 2852, Reward:  168.10, Score:  760, Epsilon: 0.058
# Episode 2853, Reward:  155.50, Score:  806, Epsilon: 0.058
# Episode 2854, Reward:  122.40, Score:  556, Epsilon: 0.058
# Episode 2855, Reward:  439.45, Score: 1884, Epsilon: 0.057
# Episode 2856, Reward:  348.65, Score: 1402, Epsilon: 0.057
# Episode 2857, Reward:  558.75, Score: 2418, Epsilon: 0.057
# Episode 2858, Reward:  494.15, Score: 1840, Epsilon: 0.057
# Episode 2859, Reward:  711.65, Score: 3018, Epsilon: 0.057
# Episode 2860, Reward:  663.00, Score: 2946, Epsilon: 0.057
# Episode 2861, Reward: 1590.55, Score: 6636, Epsilon: 0.057
# Episode 2862, Reward:  449.30, Score: 1964, Epsilon: 0.057
# Episode 2863, Reward:  217.85, Score:  950, Epsilon: 0.057
# Episode 2864, Reward:  201.15, Score:  898, Epsilon: 0.057
# Episode 2865, Reward:  334.90, Score: 1370, Epsilon: 0.057
# Episode 2866, Reward:  624.60, Score: 2458, Epsilon: 0.057
# Episode 2867, Reward:  522.90, Score: 2184, Epsilon: 0.057
# Episode 2868, Reward:  470.75, Score: 1728, Epsilon: 0.057
# Episode 2869, Reward:  411.00, Score: 1634, Epsilon: 0.057
# Episode 2870, Reward:  647.60, Score: 2652, Epsilon: 0.057
# Episode 2871, Reward:  528.65, Score: 2188, Epsilon: 0.057
# Episode 2872, Reward:  538.70, Score: 2148, Epsilon: 0.057
# Episode 2873, Reward: 1640.60, Score: 6368, Epsilon: 0.056
# Episode 2874, Reward: 1070.45, Score: 4256, Epsilon: 0.056
# Episode 2875, Reward:  373.95, Score: 1678, Epsilon: 0.056
# Episode 2876, Reward:  341.90, Score: 1400, Epsilon: 0.056
# Episode 2877, Reward:  142.05, Score:  728, Epsilon: 0.056
# Episode 2878, Reward:  991.50, Score: 4116, Epsilon: 0.056
# Episode 2879, Reward:  568.35, Score: 2424, Epsilon: 0.056
# Episode 2880, Reward:  228.50, Score: 1106, Epsilon: 0.056
# Episode 2881, Reward:  544.40, Score: 2040, Epsilon: 0.056
# Episode 2882, Reward:  195.00, Score:  764, Epsilon: 0.056
# Episode 2883, Reward:  456.90, Score: 1748, Epsilon: 0.056
# Episode 2884, Reward:  569.65, Score: 2372, Epsilon: 0.056
# Episode 2885, Reward:  336.05, Score: 1334, Epsilon: 0.056
# Episode 2886, Reward:  238.65, Score:  986, Epsilon: 0.056
# Episode 2887, Reward:  443.50, Score: 1792, Epsilon: 0.056
# Episode 2888, Reward:  680.35, Score: 2968, Epsilon: 0.056
# Episode 2889, Reward: 2069.60, Score: 8648, Epsilon: 0.056
# Checkpoint saved at episode 2889, best score: 8648.00
# Episode 2890, Reward:  854.80, Score: 3418, Epsilon: 0.055
# Episode 2891, Reward:  271.20, Score: 1220, Epsilon: 0.055
# Episode 2892, Reward: 1215.35, Score: 5064, Epsilon: 0.055
# Episode 2893, Reward:  262.25, Score: 1272, Epsilon: 0.055
# Episode 2894, Reward:  651.05, Score: 2808, Epsilon: 0.055
# Episode 2895, Reward: 1536.75, Score: 5906, Epsilon: 0.055
# Episode 2896, Reward:  210.65, Score:  966, Epsilon: 0.055
# Episode 2897, Reward:  887.90, Score: 3686, Epsilon: 0.055
# Episode 2898, Reward:  400.35, Score: 1744, Epsilon: 0.055
# Episode 2899, Reward:  137.20, Score:  716, Epsilon: 0.055
# Episode 2900, Reward:  674.75, Score: 2620, Epsilon: 0.055
# Checkpoint saved at episode 2900, best score: 8648.00
# Episode 2901, Reward:  237.30, Score: 1066, Epsilon: 0.055
# Episode 2902, Reward:  924.50, Score: 3518, Epsilon: 0.055
# Episode 2903, Reward: 1437.95, Score: 5606, Epsilon: 0.055
# Episode 2904, Reward:  306.80, Score: 1280, Epsilon: 0.055
# Episode 2905, Reward:  108.90, Score:  634, Epsilon: 0.055
# Episode 2906, Reward:  187.65, Score:  786, Epsilon: 0.055
# Episode 2907, Reward:  459.30, Score: 1964, Epsilon: 0.055
# Episode 2908, Reward: 1542.85, Score: 6698, Epsilon: 0.055
# Episode 2909, Reward:  550.85, Score: 2504, Epsilon: 0.054
# Episode 2910, Reward:  681.05, Score: 2672, Epsilon: 0.054
# Episode 2911, Reward:  737.70, Score: 3230, Epsilon: 0.054
# Episode 2912, Reward:  108.65, Score:  582, Epsilon: 0.054
# Episode 2913, Reward:  168.10, Score:  848, Epsilon: 0.054
# Episode 2914, Reward:  413.50, Score: 1636, Epsilon: 0.054
# Episode 2915, Reward:  201.20, Score:  822, Epsilon: 0.054
# Episode 2916, Reward:  673.50, Score: 2696, Epsilon: 0.054
# Episode 2917, Reward:  439.50, Score: 1866, Epsilon: 0.054
# Episode 2918, Reward:  912.35, Score: 3530, Epsilon: 0.054
# Episode 2919, Reward: 1188.20, Score: 4708, Epsilon: 0.054
# Episode 2920, Reward:  196.40, Score:  964, Epsilon: 0.054
# Episode 2921, Reward: 2461.05, Score: 10010, Epsilon: 0.054
# Checkpoint saved at episode 2921, best score: 10010.00
# Episode 2922, Reward:  205.80, Score:  892, Epsilon: 0.054
# Episode 2923, Reward:  326.90, Score: 1318, Epsilon: 0.054
# Episode 2924, Reward:  279.65, Score: 1112, Epsilon: 0.054
# Episode 2925, Reward:  320.25, Score: 1394, Epsilon: 0.054
# Episode 2926, Reward:  201.25, Score:  936, Epsilon: 0.054
# Episode 2927, Reward:  131.30, Score:  582, Epsilon: 0.053
# Episode 2928, Reward:  660.90, Score: 2888, Epsilon: 0.053
# Episode 2929, Reward:  210.75, Score: 1022, Epsilon: 0.053
# Episode 2930, Reward:  171.55, Score:  782, Epsilon: 0.053
# Episode 2931, Reward:  713.95, Score: 2812, Epsilon: 0.053
# Episode 2932, Reward:  847.50, Score: 3734, Epsilon: 0.053
# Episode 2933, Reward:  159.75, Score:  724, Epsilon: 0.053
# Episode 2934, Reward: 1091.30, Score: 4616, Epsilon: 0.053
# Episode 2935, Reward: 1133.70, Score: 4576, Epsilon: 0.053
# Episode 2936, Reward:  242.90, Score: 1184, Epsilon: 0.053
# Episode 2937, Reward:   97.35, Score:  484, Epsilon: 0.053
# Episode 2938, Reward:  753.60, Score: 3088, Epsilon: 0.053
# Episode 2939, Reward:  297.10, Score: 1398, Epsilon: 0.053
# Episode 2940, Reward:  637.20, Score: 2668, Epsilon: 0.053
# Episode 2941, Reward:  250.85, Score: 1022, Epsilon: 0.053
# Episode 2942, Reward:  389.25, Score: 1462, Epsilon: 0.053
# Episode 2943, Reward:  294.30, Score: 1006, Epsilon: 0.053
# Episode 2944, Reward:  226.95, Score: 1068, Epsilon: 0.053
# Episode 2945, Reward:  187.50, Score:  872, Epsilon: 0.053
# Episode 2946, Reward:  669.40, Score: 2974, Epsilon: 0.052
# Episode 2947, Reward:  157.35, Score:  702, Epsilon: 0.052
# Episode 2948, Reward:  598.85, Score: 2330, Epsilon: 0.052
# Episode 2949, Reward: 1471.90, Score: 6142, Epsilon: 0.052
# Episode 2950, Reward:  179.75, Score:  814, Epsilon: 0.052
# Checkpoint saved at episode 2950, best score: 10010.00
# Episode 2951, Reward:   96.25, Score:  508, Epsilon: 0.052
# Episode 2952, Reward:  175.00, Score:  910, Epsilon: 0.052
# Episode 2953, Reward:  493.95, Score: 1972, Epsilon: 0.052
# Episode 2954, Reward:  215.95, Score:  882, Epsilon: 0.052
# Episode 2955, Reward:  316.10, Score: 1300, Epsilon: 0.052
# Episode 2956, Reward:  175.70, Score:  826, Epsilon: 0.052
# Episode 2957, Reward:  213.85, Score: 1098, Epsilon: 0.052
# Episode 2958, Reward:  203.95, Score: 1076, Epsilon: 0.052
# Episode 2959, Reward:  202.65, Score:  846, Epsilon: 0.052
# Episode 2960, Reward:  570.90, Score: 2222, Epsilon: 0.052
# Episode 2961, Reward:  250.90, Score: 1168, Epsilon: 0.052
# Episode 2962, Reward:   89.05, Score:  410, Epsilon: 0.052
# Episode 2963, Reward:  116.80, Score:  538, Epsilon: 0.052
# Episode 2964, Reward:  232.65, Score:  984, Epsilon: 0.052
# Episode 2965, Reward:  896.45, Score: 3652, Epsilon: 0.051
# Episode 2966, Reward:  168.20, Score:  618, Epsilon: 0.051
# Episode 2967, Reward:  178.50, Score:  716, Epsilon: 0.051
# Episode 2968, Reward:  280.10, Score: 1416, Epsilon: 0.051
# Episode 2969, Reward:  207.40, Score:  932, Epsilon: 0.051
# Episode 2970, Reward:  178.20, Score:  784, Epsilon: 0.051
# Episode 2971, Reward:  279.10, Score: 1302, Epsilon: 0.051
# Episode 2972, Reward:  400.90, Score: 1648, Epsilon: 0.051
# Episode 2973, Reward:  229.00, Score:  954, Epsilon: 0.051
# Episode 2974, Reward:  526.70, Score: 2390, Epsilon: 0.051
# Episode 2975, Reward:  215.65, Score: 1078, Epsilon: 0.051
# Episode 2976, Reward:  148.25, Score:  638, Epsilon: 0.051
# Episode 2977, Reward:  215.15, Score:  822, Epsilon: 0.051
# Episode 2978, Reward:  217.35, Score:  950, Epsilon: 0.051
# Episode 2979, Reward:  798.15, Score: 3538, Epsilon: 0.051
# Episode 2980, Reward:  534.15, Score: 2102, Epsilon: 0.051
# Episode 2981, Reward:  484.10, Score: 2042, Epsilon: 0.051
# Episode 2982, Reward:  310.20, Score: 1358, Epsilon: 0.051
# Episode 2983, Reward:  609.75, Score: 2612, Epsilon: 0.051
# Episode 2984, Reward:  452.65, Score: 1960, Epsilon: 0.051
# Episode 2985, Reward:  707.35, Score: 3040, Epsilon: 0.050
# Episode 2986, Reward:  547.85, Score: 2576, Epsilon: 0.050
# Episode 2987, Reward:  319.70, Score: 1488, Epsilon: 0.050
# Episode 2988, Reward:  401.50, Score: 1852, Epsilon: 0.050
# Episode 2989, Reward:  662.80, Score: 2402, Epsilon: 0.050
# Episode 2990, Reward:  441.60, Score: 1824, Epsilon: 0.050
# Episode 2991, Reward:  557.70, Score: 2318, Epsilon: 0.050
# Episode 2992, Reward:  336.30, Score: 1484, Epsilon: 0.050
# Episode 2993, Reward:  216.20, Score:  996, Epsilon: 0.050
# Episode 2994, Reward:  417.75, Score: 1916, Epsilon: 0.050
# Episode 2995, Reward:   79.05, Score:  438, Epsilon: 0.050
# Episode 2996, Reward:  334.15, Score: 1488, Epsilon: 0.050
# Episode 2997, Reward:  134.70, Score:  592, Epsilon: 0.050
# Episode 2998, Reward:  147.00, Score:  710, Epsilon: 0.050
# Episode 2999, Reward:  561.65, Score: 2322, Epsilon: 0.050
# Episode 3000, Reward:  315.45, Score: 1238, Epsilon: 0.050
# Checkpoint saved at episode 3000, best score: 10010.00

# %%
from scipy.ndimage import gaussian_filter1d

reward_smooth = gaussian_filter1d(reward_history, sigma=50)
score_smooth = gaussian_filter1d(score_history, sigma=50)

# 畫圖
# plt.figure(figsize=(10, 5))
plt.plot(reward_history, label='Total Reward', alpha=0.8)
plt.plot(score_history, label='Score', alpha=0.8)
plt.plot(reward_smooth, label='Smoothed Total Reward', linewidth=2)
plt.plot(score_smooth, label='Smoothed Score', linewidth=2)

plt.legend(loc='upper left')
plt.xlabel("Episode")
plt.ylabel("Value")
plt.title("Training Reward Over Episodes")
plt.grid(True)
plt.tight_layout()
# plt.savefig("dqn_training_curve.png")
